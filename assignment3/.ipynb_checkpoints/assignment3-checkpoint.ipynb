# %%
import csv
import random as r
import sympy
import queue as q

# %%
def hashing(obbject, qq, ww, mmod):
    obbbject.q= qq
    obbject.w = ww
    obbject.mod= modd
    
def hashingCompute(obbject, e):
    return(obbject.q*e + obbject.w)% obbject.mod

def adding(obbject)

# %%
class minSample(object):

    def __init__(a, maximumSize):
        a.ms = maximumSize
        a.sample = q.PriorityQueue(maxsize=maximumSize)

    def adding(a, j): # This method used values between 0 - 100 which are uniform. It will check if the new tuple contains a higher score than the first element in the priorityqueue. It removes this first tuple when the score is lower and then will adding a new.
            # And the else statement if the tuple which is orginal is putted back , or when the priority is not full.
        
        score = r.uniform(0, 100)
        tuple = (score, j)
        if a.sample.full():
            firstElement = a.sample.get()
            firstElementScore = firstElement[0]
            if score > firstElementScore:
                a.sample.put(tuple) 
            else:
                a.sample.put(firstElement) 
     
        else:
            a.sample.put(tuple)

    def countSort(a):# This method is sorting in a descending order with the use of a Priority Queue
        frequency = a.counting()
        pqueue = q.PriorityQueue()
        
        for ip in frequency:
            
            pqueue.put((a.ms - frequency[ip], ip))
            
        result = dict()
        
        while not pqueue.empty():
            j = pqueue.get()
            result[j[1]] = a.ms - j[0]
        return result
    
    
    def counting(a): # This method is counting the frequencies of the IP addresses which are sampled
        counting = dict()

        while not a.sample.empty():
            ip = a.sample.get()[1]
            if ip in counting:
                counting[ip] = counting[ip]+ 1
            else:
                counting[ip] = 1
        return counting
    
    ##SECOND CLASS... namen en teksten nog veranderen.
    
    
    def sortValue(frequencies, maximumValue):
        pqueue2 = q.PriorityQueue()
        for ip in frequencies:
        # This is a trick to store frequencies in descending order:
        # subtract the actual frequency of the maximum size of the sample.
            pqueue2.put((maximumValue - frequencies[ip], ip))
        result = dict()
        while not pqueue2.empty():
            j = pqueue2.get()
        # Apply correction to get the actual frequencies back.
            result[j[1]] = maximumValue - j[0]
        return result

   #methode namen nog veranderen.
    
def select_first_k(dictionary, k):
    keyset = list(dictionary.keys())
    result = dict()
    for i in range(k):
        key = keyset[i]
        result[key] = dictionary[key]
    return result

def keys_in_same_position(dict1, dict2):
    counting = 0
    keys1, keys2 = list(dict1.keys()), list(dict2.keys())
    for i in range(len(keys1)):
        if keys1[i] == keys2[i]:
            counting = counting + 1
    return counting
    
def keys_in_common(dict1, dict2):
    counting = 0
    for k in dict1:
        if k in dict2:
            counting = counting + 1
    return counting

# %% [markdown]
# ###SAMPLING TASK###

# %%
frequency = dict()
amount = 0
k= 10
size = 10000
adressList = [] 
samples = minSample(size)


with open("Data\capture20110816-2.pcap.netflow.labeled") as data:
    reader = csv.reader(data, delimiter=" ")
    for a, line in enumerate(reader):
        if a < 1:
            continue
            
        splitting = line[1].split("\t") 
        for b, c in enumerate(splitting):
            if c == "->":
                ip = splitting[b+1].split(":")[0]
                
                if(ip!= "ff02") and (ip!= "Broadcast"):
                    samples.adding(ip) 
                    
                    if ip in frequency:
                        frequency[ip] = frequency[ip]+ 1 
                        
                    else:
                        frequency[ip] = 1
                    
                    adressList.append(ip) 
                    amount = amount+ 1
                    
                    
                    
                    
#print(ip) 
          


totalSorting = minSample.sortValue(frequency,amount) 
samplingSorting = samples.countSort()


#destinationIP = %amount 
#print('Amount destination IP addresses %i' %amount)
print('Total frequencies in a descending order' %frequency)
#print(frequency)  
print(totalSorting)
# Out:
# Total frequencies in a descending order
# {'147.32.84.229': 60842, '147.32.84.59': 49223, '147.32.80.9': 47001, '147.32.84.138': 19607, '147.32.84.94': 15489, '147.32.80.13': 5817, '147.32.85.7': 4235, '147.32.85.25': 3242, '147.32.85.8': 3152, '147.32.86.134': 2516, '147.32.84.172': 2476, '88.176.79.163': 2464, '147.32.85.34': 2031, '147.32.86.187': 1814, '147.32.86.168': 1708, '147.32.86.58': 1619, '76.13.114.90': 1514, '147.32.86.44': 1396, '147.32.84.184': 1369, '147.32.84.19': 1197, '147.32.86.165': 1161, '147.32.84.164': 1149, '147.32.84.171': 1092, '147.32.85.26': 1065, '147.32.87.238': 1057, '147.32.84.134': 1053, '147.32.84.170': 986, '74.125.39.125': 972, '147.32.85.23': 944, '147.32.86.20': 907, '147.32.87.220': 874, '188.138.84.239': 835, '147.32.84.2': 784, '147.32.86.50': 751, '147.32.85.123': 745, '89.185.253.133': 720, '74.125.232.213': 717, '74.125.232.215': 697, '147.32.86.223': 693, '192.168.95.255': 687, '74.125.232.214': 653, '88.86.102.50': 644, '147.32.86.172': 607, '147.32.86.171': 604, '147.32.84.130': 595, '147.32.85.87': 595, '147.32.85.117': 570, '209.85.148.103': 567, '74.125.232.216': 546, '74.125.232.223': 546, '74.125.232.204': 541, '87.98.230.229': 534, '147.32.87.36': 526, '147.32.87.252': 522, '147.32.85.2': 518, '147.32.85.74': 512, '147.32.86.190': 512, '147.32.85.88': 511, '147.32.84.111': 509, '147.32.84.194': 506, '46.135.141.15': 501, '147.32.86.77': 478, '195.250.146.107': 461, '209.85.148.106': 461, '74.125.232.205': 458, '209.85.149.132': 444, '147.32.84.168': 441, '209.85.149.189': 435, '147.32.84.36': 431, '147.32.84.216': 429, '74.125.232.200': 422, '209.85.148.105': 414, '147.32.86.74': 411, '147.32.85.21': 407, '147.32.84.162': 403, '46.4.